# %% [markdown]
# # Predicting a studying song's success

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# url = "https://es.wikipedia.org/wiki/Anexo:Canciones_m%C3%A1s_reproducidas_en_Spotify"

# %% [markdown]
# response = requests.get(url)
# response.status_code # 200 status code means OK!

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# soup

# %% [markdown]
# prestab = soup.select("table")[0]
#
# prestab.select("tr td")

# %% [markdown]
# song = []
# for title in prestab.select("tr td:nth-child(2)"):
#     song.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# song

# %% [markdown]
# artist = []
# for title in prestab.select("tr td:nth-child(3)"):
#     artist.append(title.get_text())
#     #print(title.get_text())
# #mw-content-text > div.mw-parser-output > table:nth-child(9) > tbody > tr:nth-child(4) > td:nth-child(3)

# %% [markdown]
# artist

# %% [markdown]
# replays = []
# for title in prestab.select("tr td:nth-child(5)"):
#     replays.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# replays

# %% [markdown]
# song = pd.DataFrame(song)
# artist = pd.DataFrame(artist)
# replays = pd.DataFrame(replays)
# print(len(song))
# print(len(artist))
# print(len(replays))

# %% [markdown]
# df_1 = pd.concat([replays], axis = 1)
# df_1.columns = ['replays (billion)']
# df_1 = df_1.replace(',','', regex=True)
# df_1 = df_1.astype(float)
# df_1

# %% [markdown]
# ## Getting access to spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='<your client id here>',
#                                                           client_secret='<your client secret here>'))

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# ### Coding in spotify

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("37i9dQZF1DX8NTLI2TtZa6")
len(all_tracks)
# Out:
# 220

# %%
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"]) for artist in track["artists"]]

# %%
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

# %%
#flattening is not in the standard library but used a lot. you'll thank me later
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
def get_name_artists_from_playlist(input_playlist):
    return list(map(get_name_artist_from_playlist_item, input_playlist))

# %%
song_artist = get_name_artists_from_playlist(all_tracks)
len(song_artist)
# Out:
# 220

# %%
song_artist = [song_artist[i][0] for i in range(len(song_artist))]

# %%
df = pd.DataFrame(song_artist, columns = ['song', 'artist'])
df
# Out:
#                song          artist
# 0          Sketches    Ever So Blue
# 1           Caliesa       Max Sauer
# 2       Yet To Come   Józef Gatysik
# 3       Notre terre  Mattéo Roussel
# 4    primeiro verão    Lílian Pinto
# ..              ...             ...
# 215        Delphine     Mounia Sedé
# 216       Raindrops            Giné
# 217         Sparrow    Ana Petrovna
# 218          Onthou    Ever So Blue
# 219        Vitality      Jamie Troy
#
# [220 rows x 2 columns]

# %%
uris = [(all_tracks[i]["track"]["uri"]) for i in range(len(all_tracks))]

uris = pd.DataFrame(uris, columns = ['uri'])
uris
# Out:
#                                       uri
# 0    spotify:track:4g7wXitUwsMOjZMA9m1vy6
# 1    spotify:track:4Lj9Ap737rbqtH2Zd6skxa
# 2    spotify:track:3tDmQa16JU8ORtzOwEsqei
# 3    spotify:track:5kHdX3qzFelWIDOiUAs96C
# 4    spotify:track:2V1y8aiJS9HMFqh51dNVs4
# ..                                    ...
# 215  spotify:track:2HkjTkR8KB5CKa2UyrUMHf
# 216  spotify:track:6w2FKNd3zDRJGJ0krZxWPi
# 217  spotify:track:2zFYk6wwcF2fTXrvsMaeEP
# 218  spotify:track:0CoSBNNeO8JgayAfLttECk
# 219  spotify:track:10tC4GQIfS6saBeCfXda1h
#
# [220 rows x 1 columns]

# %%
track_pop = [(all_tracks[i]["track"]["popularity"]) for i in range(len(all_tracks))]
track_pop = pd.DataFrame(track_pop, columns = ['popularity'])
track_pop
# Out:
#      popularity
# 0            48
# 1            58
# 2            54
# 3            52
# 4            56
# ..          ...
# 215          42
# 216          43
# 217          43
# 218          48
# 219          46
#
# [220 rows x 1 columns]

# %%
track_pop['popularity'].value_counts()
# Out:
# 47    32
# 46    19
# 51    17
# 45    16
# 48    14
# 52    14
# 43    13
# 53    13
# 50    13
# 49    10
# 54     8
# 40     7
# 41     7
# 42     6
# 44     6
# 39     5
# 55     4
# 56     3
# 0      3
# 38     2
# 57     2
# 59     2
# 1      2
# 58     1
# 60     1
# Name: popularity, dtype: int64

# %%
# track_pop['popularity'] = track_pop['popularity'].astype(float)
# track_pop['popularity'] = [ 1 if i>=9 else 0 for i in track_pop['popularity']]
# track_pop['popularity'].value_counts()

# %%
sau_df = pd.concat([df, uris], axis = 1)
sau_df
# Out:
#                song          artist                                   uri
# 0          Sketches    Ever So Blue  spotify:track:4g7wXitUwsMOjZMA9m1vy6
# 1           Caliesa       Max Sauer  spotify:track:4Lj9Ap737rbqtH2Zd6skxa
# 2       Yet To Come   Józef Gatysik  spotify:track:3tDmQa16JU8ORtzOwEsqei
# 3       Notre terre  Mattéo Roussel  spotify:track:5kHdX3qzFelWIDOiUAs96C
# 4    primeiro verão    Lílian Pinto  spotify:track:2V1y8aiJS9HMFqh51dNVs4
# ..              ...             ...                                   ...
# 215        Delphine     Mounia Sedé  spotify:track:2HkjTkR8KB5CKa2UyrUMHf
# 216       Raindrops            Giné  spotify:track:6w2FKNd3zDRJGJ0krZxWPi
# 217         Sparrow    Ana Petrovna  spotify:track:2zFYk6wwcF2fTXrvsMaeEP
# 218          Onthou    Ever So Blue  spotify:track:0CoSBNNeO8JgayAfLttECk
# 219        Vitality      Jamie Troy  spotify:track:10tC4GQIfS6saBeCfXda1h
#
# [220 rows x 3 columns]

# %%
sau_df = sau_df[~ sau_df['uri'].str.contains('spotify:local')]

# %%
audio_features = [sp.audio_features(i) for i in sau_df['uri']]

# %%
audio_features = [audio_features[i][0] for i in range(len(audio_features))]

# %%
af_df = pd.DataFrame.from_dict(data = audio_features, orient = 'columns').pivot_table(index = 'uri').reset_index()
#este from_dict es para hacer un data frame de un diccionario
af_df
# Out:
#                                       uri  acousticness  danceability  \
# 0    spotify:track:000tG7ZCNMDFLzIxobVSUZ         0.994         0.431
# 1    spotify:track:05RikarvGDzw4HktIAxxKR         0.974         0.353
# 2    spotify:track:0BXq9t3wTA8HMqFPvGxZYf         0.991         0.395
# 3    spotify:track:0C2q5FBAGtuFopEx96ayCf         0.993         0.352
# 4    spotify:track:0Ck0h2BOe48JxLlPQrl1sV         0.984         0.482
# ..                                    ...           ...           ...
# 215  spotify:track:7pDMaPfKcCiBovr98OYb5d         0.992         0.618
# 216  spotify:track:7r8OKeD5bIacpidpuEx1SG         0.994         0.387
# 217  spotify:track:7wksCozvMX6I0imUoTWBCE         0.980         0.503
# 218  spotify:track:7x29ikGEInCzC5IrN3zMhI         0.935         0.289
# 219  spotify:track:7z9zhEtAOSL3DeQgORiFnH         0.988         0.394
#
#      duration_ms   energy  instrumentalness  key  liveness  loudness  mode  \
# 0         160091  0.04860             0.906    6     0.107   -23.585     1
# 1         133000  0.39500             0.898    5     0.108   -27.484     1
# 2         114400  0.03070             0.896    2     0.109   -31.070     1
# 3         129750  0.14500             0.954    9     0.105   -24.740     0
# 4         137500  0.02690             0.883   10     0.100   -28.775     1
# ..           ...      ...               ...  ...       ...       ...   ...
# 215       174355  0.04540             0.948    7     0.103   -26.528     0
# 216       178000  0.08900             0.926    7     0.129   -31.737     0
# 217       170741  0.04090             0.851    3     0.108   -30.746     1
# 218       180308  0.00882             0.898    7     0.115   -28.999     1
# 219       154909  0.05660             0.920    0     0.103   -25.925     0
#
#      speechiness    tempo  time_signature  valence
# 0         0.0334  156.648               3   0.3450
# 1         0.0315  136.843               4   0.4290
# 2         0.0482  131.514               4   0.3860
# 3         0.0441   94.466               4   0.2750
# 4         0.0416  126.013               4   0.0373
# ..           ...      ...             ...      ...
# 215       0.0385   94.506               3   0.5290
# 216       0.0450  125.677               4   0.1170
# 217       0.0498  120.425               1   0.4850
# 218       0.0389  133.912               4   0.1750
# 219       0.0350  135.534               3   0.1970
#
# [220 rows x 14 columns]

# %%
final_df_1 = sau_df.merge(right = af_df, on = 'uri')
final_df = pd.concat([final_df_1, track_pop], axis = 1)
final_df
# Out:
#                song          artist                                   uri  \
# 0          Sketches    Ever So Blue  spotify:track:4g7wXitUwsMOjZMA9m1vy6
# 1           Caliesa       Max Sauer  spotify:track:4Lj9Ap737rbqtH2Zd6skxa
# 2       Yet To Come   Józef Gatysik  spotify:track:3tDmQa16JU8ORtzOwEsqei
# 3       Notre terre  Mattéo Roussel  spotify:track:5kHdX3qzFelWIDOiUAs96C
# 4    primeiro verão    Lílian Pinto  spotify:track:2V1y8aiJS9HMFqh51dNVs4
# ..              ...             ...                                   ...
# 215        Delphine     Mounia Sedé  spotify:track:2HkjTkR8KB5CKa2UyrUMHf
# 216       Raindrops            Giné  spotify:track:6w2FKNd3zDRJGJ0krZxWPi
# 217         Sparrow    Ana Petrovna  spotify:track:2zFYk6wwcF2fTXrvsMaeEP
# 218          Onthou    Ever So Blue  spotify:track:0CoSBNNeO8JgayAfLttECk
# 219        Vitality      Jamie Troy  spotify:track:10tC4GQIfS6saBeCfXda1h
#
#      acousticness  danceability  duration_ms   energy  instrumentalness  key  \
# 0           0.993         0.353       157127  0.09440             0.938   10
# 1           0.992         0.373       172135  0.00694             0.952    6
# 2           0.990         0.543       214615  0.06660             0.921   11
# 3           0.986         0.286       158500  0.28700             0.918    9
# 4           0.995         0.330       208625  0.05760             0.912    4
# ..            ...           ...          ...      ...               ...  ...
# 215         0.995         0.416       142698  0.13200             0.942   10
# 216         0.994         0.284       114199  0.02390             0.835    5
# 217         0.990         0.478       130308  0.11500             0.945    7
# 218         0.996         0.307       128333  0.05000             0.940    0
# 219         0.993         0.314       126127  0.02350             0.863    1
#
#      liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0      0.1030   -26.851     1       0.0386  147.411               4    0.416
# 1      0.0964   -28.016     0       0.0451  128.379               4    0.173
# 2      0.1090   -23.158     1       0.0380  134.053               3    0.256
# 3      0.1030   -26.371     1       0.0398  136.919               3    0.514
# 4      0.0970   -23.233     1       0.0387   69.092               5    0.086
# ..        ...       ...   ...          ...      ...             ...      ...
# 215    0.1100   -23.592     0       0.0508  110.933               4    0.482
# 216    0.1130   -24.133     0       0.0433  180.620               3    0.712
# 217    0.1160   -17.982     0       0.0471   95.400               1    0.286
# 218    0.1050   -27.964     1       0.0345  138.484               4    0.410
# 219    0.1070   -28.486     1       0.0396   70.842               4    0.208
#
#      popularity
# 0            48
# 1            58
# 2            54
# 3            52
# 4            56
# ..          ...
# 215          42
# 216          43
# 217          43
# 218          48
# 219          46
#
# [220 rows x 17 columns]

# %%
numericals_1 = final_df.select_dtypes(include = np.number)

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlations_matrix = numericals_1.corr()
sns.heatmap(correlations_matrix, sns.set(rc = {'figure.figsize':(12,8)}), linewidths=3, annot=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: vmin. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
