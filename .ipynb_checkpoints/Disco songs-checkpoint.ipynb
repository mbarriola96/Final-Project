# %% [markdown]
# # Predicting a energy songs success

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# url = "https://es.wikipedia.org/wiki/Anexo:Canciones_m%C3%A1s_reproducidas_en_Spotify"

# %% [markdown]
# response = requests.get(url)
# response.status_code # 200 status code means OK!

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# soup

# %% [markdown]
# prestab = soup.select("table")[0]
#
# prestab.select("tr td")

# %% [markdown]
# song = []
# for title in prestab.select("tr td:nth-child(2)"):
#     song.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# song

# %% [markdown]
# artist = []
# for title in prestab.select("tr td:nth-child(3)"):
#     artist.append(title.get_text())
#     #print(title.get_text())
# #mw-content-text > div.mw-parser-output > table:nth-child(9) > tbody > tr:nth-child(4) > td:nth-child(3)

# %% [markdown]
# artist

# %% [markdown]
# replays = []
# for title in prestab.select("tr td:nth-child(5)"):
#     replays.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# replays

# %% [markdown]
# song = pd.DataFrame(song)
# artist = pd.DataFrame(artist)
# replays = pd.DataFrame(replays)
# print(len(song))
# print(len(artist))
# print(len(replays))

# %% [markdown]
# df_1 = pd.concat([replays], axis = 1)
# df_1.columns = ['replays (billion)']
# df_1 = df_1.replace(',','', regex=True)
# df_1 = df_1.astype(float)
# df_1

# %% [markdown]
# ## Getting access to spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='<your client id here>',
#                                                           client_secret='<your client secret here>'))

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# ### Coding in spotify

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("37i9dQZF1DWYp5sAHdz27Y")
len(all_tracks)
# Out:
# 150

# %%
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"]) for artist in track["artists"]]

# %%
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

# %%
#flattening is not in the standard library but used a lot. you'll thank me later
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
def get_name_artists_from_playlist(input_playlist):
    return list(map(get_name_artist_from_playlist_item, input_playlist))

# %%
song_artist = get_name_artists_from_playlist(all_tracks)
len(song_artist)
# Out:
# 150

# %%
song_artist = [song_artist[i][0] for i in range(len(song_artist))]

# %%
df = pd.DataFrame(song_artist, columns = ['song', 'artist'])
df
# Out:
#                                             song          artist
# 0                                     Todo De Ti  Rauw Alejandro
# 1                                          Pepas         Farruko
# 2        Tiago PZK: Bzrp Music Sessions, Vol. 48        Bizarrap
# 3                                Beautiful Girls     Danny Avila
# 4                                   Sweet Dreams     Alan Walker
# ..                                           ...             ...
# 145  Faith (with Dolly Parton) [feat. Mr. Probz]        Galantis
# 146                                     Before U    Sonny Fodera
# 147             I Found You (with Calvin Harris)    benny blanco
# 148                                 Up All Night           R3HAB
# 149         Stand By (#CWC19) (feat. Rudimental)           LORYN
#
# [150 rows x 2 columns]

# %%
uris = [(all_tracks[i]["track"]["uri"]) for i in range(len(all_tracks))]

uris = pd.DataFrame(uris, columns = ['uri'])
uris
# Out:
#                                       uri
# 0    spotify:track:4fSIb4hdOQ151TILNsSEaF
# 1    spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 2    spotify:track:2Gq636OOGgxCTqEuzCZhsa
# 3    spotify:track:1tHV6RsOZkrYk8v40AWaGf
# 4    spotify:track:4uDhts78RdwIDjEqPrYVKp
# ..                                    ...
# 145  spotify:track:35MKhw2YBKApmD7fAnPERC
# 146  spotify:track:1YK1uWCZLaljd7kgjaC7bH
# 147  spotify:track:1kQhi22kyluRCnIPAXtxEZ
# 148  spotify:track:5RugEn59RTnWE4IM4uBaC9
# 149  spotify:track:05P4BYqVauVxy0w9g6w2D9
#
# [150 rows x 1 columns]

# %%
track_pop = [(all_tracks[i]["track"]["popularity"]) for i in range(len(all_tracks))]
track_pop = pd.DataFrame(track_pop, columns = ['popularity'])
track_pop
# Out:
#      popularity
# 0            82
# 1            87
# 2            84
# 3            48
# 4            75
# ..          ...
# 145          59
# 146          46
# 147          52
# 148          49
# 149          43
#
# [150 rows x 1 columns]

# %%
track_pop['popularity'].value_counts()
# Out:
# 0     11
# 61     8
# 82     7
# 48     7
# 74     6
# 62     5
# 71     5
# 59     5
# 56     5
# 68     4
# 69     4
# 72     4
# 76     4
# 65     4
# 77     4
# 80     3
# 58     3
# 75     3
# 60     3
# 42     3
# 70     3
# 57     3
# 45     3
# 78     2
# 50     2
# 46     2
# 84     2
# 49     2
# 40     2
# 1      2
# 66     2
# 67     2
# 73     2
# 81     2
# 47     2
# 64     2
# 18     1
# 52     1
# 79     1
# 37     1
# 44     1
# 34     1
# 86     1
# 16     1
# 92     1
# 83     1
# 87     1
# 13     1
# 54     1
# 19     1
# 35     1
# 39     1
# 43     1
# Name: popularity, dtype: int64

# %%
# track_pop['popularity'] = track_pop['popularity'].astype(float)
# track_pop['popularity'] = [ 1 if i>=9 else 0 for i in track_pop['popularity']]
# track_pop['popularity'].value_counts()

# %%
sau_df = pd.concat([df, uris], axis = 1)
sau_df
# Out:
#                                             song          artist  \
# 0                                     Todo De Ti  Rauw Alejandro
# 1                                          Pepas         Farruko
# 2        Tiago PZK: Bzrp Music Sessions, Vol. 48        Bizarrap
# 3                                Beautiful Girls     Danny Avila
# 4                                   Sweet Dreams     Alan Walker
# ..                                           ...             ...
# 145  Faith (with Dolly Parton) [feat. Mr. Probz]        Galantis
# 146                                     Before U    Sonny Fodera
# 147             I Found You (with Calvin Harris)    benny blanco
# 148                                 Up All Night           R3HAB
# 149         Stand By (#CWC19) (feat. Rudimental)           LORYN
#
#                                       uri
# 0    spotify:track:4fSIb4hdOQ151TILNsSEaF
# 1    spotify:track:5fwSHlTEWpluwOM0Sxnh5k
# 2    spotify:track:2Gq636OOGgxCTqEuzCZhsa
# 3    spotify:track:1tHV6RsOZkrYk8v40AWaGf
# 4    spotify:track:4uDhts78RdwIDjEqPrYVKp
# ..                                    ...
# 145  spotify:track:35MKhw2YBKApmD7fAnPERC
# 146  spotify:track:1YK1uWCZLaljd7kgjaC7bH
# 147  spotify:track:1kQhi22kyluRCnIPAXtxEZ
# 148  spotify:track:5RugEn59RTnWE4IM4uBaC9
# 149  spotify:track:05P4BYqVauVxy0w9g6w2D9
#
# [150 rows x 3 columns]

# %%
sau_df = sau_df[~ sau_df['uri'].str.contains('spotify:local')]

# %%
audio_features = [sp.audio_features(i) for i in sau_df['uri']]

# %%
audio_features = [audio_features[i][0] for i in range(len(audio_features))]

# %%
af_df = pd.DataFrame.from_dict(data = audio_features, orient = 'columns').pivot_table(index = 'uri').reset_index()
#este from_dict es para hacer un data frame de un diccionario
af_df
# Out:
#                                       uri  acousticness  danceability  \
# 0    spotify:track:02itaCXOdC54J0ISjqqFAp        0.4790         0.733
# 1    spotify:track:05P4BYqVauVxy0w9g6w2D9        0.0616         0.661
# 2    spotify:track:0E9ZjEAyAwOXZ7wJC0PD33        0.1760         0.694
# 3    spotify:track:0EdgK7ASb4kfRkW8pVMN02        0.2640         0.503
# 4    spotify:track:0KG7XrgM20KEmJrKsyFDAm        0.1010         0.584
# ..                                    ...           ...           ...
# 145  spotify:track:7dk9EBvTbbKBbFxjCAJpwK        0.1330         0.697
# 146  spotify:track:7ef4DlsgrMEH11cDZd32M6        0.0370         0.791
# 147  spotify:track:7fPuWrlpwDcHm5aHCH5D9t        0.0149         0.785
# 148  spotify:track:7qbjS6uKZlv7K08CNcEqYR        0.3290         0.766
# 149  spotify:track:7sEwsJK7Ol0J6PFV9nioxu        0.0115         0.679
#
#      duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0         147840   0.859          0.064500    9    0.1050    -5.030     0
# 1         189274   0.780          0.000000    1    0.2300    -4.738     1
# 2         184560   0.770          0.000011    6    0.1180    -5.335     1
# 3         186750   0.754          0.000058    7    0.2970    -3.634     1
# 4         234375   0.955          0.002430    7    0.0920    -4.197     0
# ..           ...     ...               ...  ...       ...       ...   ...
# 145       190772   0.836          0.000004    5    0.0754    -5.005     1
# 146       214847   0.862          0.000022    9    0.0814    -3.240     0
# 147       176219   0.721          0.004320    8    0.2850    -5.457     1
# 148       158710   0.698          0.000000    3    0.0835    -7.549     0
# 149       147255   0.879          0.015100    5    0.3430    -3.321     0
#
#      speechiness    tempo  time_signature  valence
# 0         0.0330  124.948               4    0.520
# 1         0.0832  116.025               4    0.623
# 2         0.1490  125.905               4    0.163
# 3         0.0424  116.524               4    0.597
# 4         0.0507  128.040               4    0.486
# ..           ...      ...             ...      ...
# 145       0.0437  121.977               4    0.631
# 146       0.1100  123.994               4    0.592
# 147       0.0506  121.962               4    0.894
# 148       0.2280  123.926               4    0.204
# 149       0.0556  126.079               4    0.325
#
# [150 rows x 14 columns]

# %%
final_df_1 = sau_df.merge(right = af_df, on = 'uri')
final_df = pd.concat([final_df_1, track_pop], axis = 1)
final_df
# Out:
#                                             song          artist  \
# 0                                     Todo De Ti  Rauw Alejandro
# 1                                          Pepas         Farruko
# 2        Tiago PZK: Bzrp Music Sessions, Vol. 48        Bizarrap
# 3                                Beautiful Girls     Danny Avila
# 4                                   Sweet Dreams     Alan Walker
# ..                                           ...             ...
# 145  Faith (with Dolly Parton) [feat. Mr. Probz]        Galantis
# 146                                     Before U    Sonny Fodera
# 147             I Found You (with Calvin Harris)    benny blanco
# 148                                 Up All Night           R3HAB
# 149         Stand By (#CWC19) (feat. Rudimental)           LORYN
#
#                                       uri  acousticness  danceability  \
# 0    spotify:track:4fSIb4hdOQ151TILNsSEaF       0.31000         0.780
# 1    spotify:track:5fwSHlTEWpluwOM0Sxnh5k       0.00776         0.762
# 2    spotify:track:2Gq636OOGgxCTqEuzCZhsa       0.47000         0.656
# 3    spotify:track:1tHV6RsOZkrYk8v40AWaGf       0.02510         0.701
# 4    spotify:track:4uDhts78RdwIDjEqPrYVKp       0.02390         0.766
# ..                                    ...           ...           ...
# 145  spotify:track:35MKhw2YBKApmD7fAnPERC       0.14500         0.547
# 146  spotify:track:1YK1uWCZLaljd7kgjaC7bH       0.12700         0.641
# 147  spotify:track:1kQhi22kyluRCnIPAXtxEZ       0.02640         0.790
# 148  spotify:track:5RugEn59RTnWE4IM4uBaC9       0.01700         0.678
# 149  spotify:track:05P4BYqVauVxy0w9g6w2D9       0.06160         0.661
#
#      duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0         199604   0.718          0.000163    3    0.0932    -3.605     0
# 1         287120   0.766          0.000070    7    0.1280    -3.955     1
# 2         160000   0.823          0.000000    1    0.1030    -3.059     0
# 3         161684   0.941          0.000065    8    0.0621    -3.675     1
# 4         138819   0.817          0.000002    7    0.1590    -4.253     1
# ..           ...     ...               ...  ...       ...       ...   ...
# 145       186805   0.795          0.000000    8    0.1100    -3.721     1
# 146       199720   0.825          0.003310    6    0.3360    -6.631     0
# 147       189165   0.865          0.089200    6    0.2400    -4.159     1
# 148       161905   0.916          0.000876    2    0.2770    -3.344     0
# 149       189274   0.780          0.000000    1    0.2300    -4.738     1
#
#      speechiness    tempo  time_signature  valence  popularity
# 0         0.0506  127.949               4    0.342          82
# 1         0.0343  130.001               4    0.442          87
# 2         0.3150   96.474               4    0.755          84
# 3         0.0453  130.009               4    0.363          48
# 4         0.0350  125.033               4    0.430          75
# ..           ...      ...             ...      ...         ...
# 145       0.0489  118.118               4    0.723          59
# 146       0.0344  125.003               4    0.627          46
# 147       0.0438  122.990               4    0.362          52
# 148       0.1200  125.944               4    0.412          49
# 149       0.0832  116.025               4    0.623          43
#
# [150 rows x 17 columns]

# %%
numericals_1 = final_df.select_dtypes(include = np.number)

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlations_matrix = numericals_1.corr()
sns.heatmap(correlations_matrix, sns.set(rc = {'figure.figsize':(12,8)}), linewidths=3, annot=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: vmin. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
