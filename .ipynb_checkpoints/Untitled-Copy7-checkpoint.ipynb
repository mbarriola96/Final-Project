# %% [markdown]
# # Predicting a relaxing song's success

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# url = "https://es.wikipedia.org/wiki/Anexo:Canciones_m%C3%A1s_reproducidas_en_Spotify"

# %% [markdown]
# response = requests.get(url)
# response.status_code # 200 status code means OK!

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# soup

# %% [markdown]
# prestab = soup.select("table")[0]
#
# prestab.select("tr td")

# %% [markdown]
# song = []
# for title in prestab.select("tr td:nth-child(2)"):
#     song.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# song

# %% [markdown]
# artist = []
# for title in prestab.select("tr td:nth-child(3)"):
#     artist.append(title.get_text())
#     #print(title.get_text())
# #mw-content-text > div.mw-parser-output > table:nth-child(9) > tbody > tr:nth-child(4) > td:nth-child(3)

# %% [markdown]
# artist

# %% [markdown]
# replays = []
# for title in prestab.select("tr td:nth-child(5)"):
#     replays.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# replays

# %% [markdown]
# song = pd.DataFrame(song)
# artist = pd.DataFrame(artist)
# replays = pd.DataFrame(replays)
# print(len(song))
# print(len(artist))
# print(len(replays))

# %% [markdown]
# df_1 = pd.concat([replays], axis = 1)
# df_1.columns = ['replays (billion)']
# df_1 = df_1.replace(',','', regex=True)
# df_1 = df_1.astype(float)
# df_1

# %% [markdown]
# ## Getting access to spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='<your client id here>',
#                                                           client_secret='<your client secret here>'))

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# ### Coding in spotify

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("6gCC8kozvUlLGTzl2YO2MR")
len(all_tracks)
# Out:
# 86

# %%
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"]) for artist in track["artists"]]

# %%
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

# %%
#flattening is not in the standard library but used a lot. you'll thank me later
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
def get_name_artists_from_playlist(input_playlist):
    return list(map(get_name_artist_from_playlist_item, input_playlist))

# %%
song_artist = get_name_artists_from_playlist(all_tracks)
len(song_artist)
# Out:
# 86

# %%
song_artist = [song_artist[i][0] for i in range(len(song_artist))]

# %%
df = pd.DataFrame(song_artist, columns = ['song', 'artist'])
df
# Out:
#                         song             artist
# 0                 Weightless      Marconi Union
# 1              The Wider Sun        Jon Hopkins
# 2              Catalina 1943             Loscil
# 3                      Theme  Jóhann Jóhannsson
# 4               Radiant City      Robin Guthrie
# ..                       ...                ...
# 81  Requiem On Frankfort Ave            Eluvium
# 82                   Candles        Jon Hopkins
# 83                Poa Alpina          Biosphere
# 84   Untitled #3 (Samskeyti)          Sigur Rós
# 85            Beyond the Sky      Emilio Bonito
#
# [86 rows x 2 columns]

# %%
uris = [(all_tracks[i]["track"]["uri"]) for i in range(len(all_tracks))]

uris = pd.DataFrame(uris, columns = ['uri'])
uris
# Out:
#                                      uri
# 0   spotify:track:6kkwzB6hXLIONkEk9JciA6
# 1   spotify:track:3BdVeHmCKUrb4LTU0Kpw7Z
# 2   spotify:track:6PJS1eFGk0YTlBoyZGPC2K
# 3   spotify:track:6shMq3iAjg2uvn36R4MpYG
# 4   spotify:track:0Z5oEza6OKWhXJBVnlCWzl
# ..                                   ...
# 81  spotify:track:06X1J1lPc0boVEpxG6UOCB
# 82  spotify:track:7aS8e5XKVWDcbyn06mF9fz
# 83  spotify:track:1TCkrnjuurf0DNLLoJxVyd
# 84  spotify:track:4o7YmNo3syL8mtvHNhwDuL
# 85  spotify:track:08adWEXNC4zjhKZZuAVMo5
#
# [86 rows x 1 columns]

# %%
track_pop = [(all_tracks[i]["track"]["popularity"]) for i in range(len(all_tracks))]
track_pop = pd.DataFrame(track_pop, columns = ['popularity'])
track_pop
# Out:
#     popularity
# 0           65
# 1            0
# 2           18
# 3            0
# 4           35
# ..         ...
# 81           0
# 82          49
# 83           0
# 84           0
# 85          18
#
# [86 rows x 1 columns]

# %%
track_pop['popularity'].value_counts()
# Out:
# 0     18
# 35     5
# 26     5
# 30     5
# 7      5
# 13     4
# 23     4
# 27     4
# 18     3
# 34     3
# 21     2
# 19     2
# 10     2
# 9      2
# 22     2
# 11     1
# 40     1
# 55     1
# 38     1
# 29     1
# 4      1
# 6      1
# 8      1
# 65     1
# 43     1
# 14     1
# 53     1
# 16     1
# 39     1
# 12     1
# 31     1
# 32     1
# 25     1
# 52     1
# 49     1
# Name: popularity, dtype: int64

# %%
# track_pop['popularity'] = track_pop['popularity'].astype(float)
# track_pop['popularity'] = [ 1 if i>=9 else 0 for i in track_pop['popularity']]
# track_pop['popularity'].value_counts()

# %%
sau_df = pd.concat([df, uris], axis = 1)
sau_df
# Out:
#                         song             artist  \
# 0                 Weightless      Marconi Union
# 1              The Wider Sun        Jon Hopkins
# 2              Catalina 1943             Loscil
# 3                      Theme  Jóhann Jóhannsson
# 4               Radiant City      Robin Guthrie
# ..                       ...                ...
# 81  Requiem On Frankfort Ave            Eluvium
# 82                   Candles        Jon Hopkins
# 83                Poa Alpina          Biosphere
# 84   Untitled #3 (Samskeyti)          Sigur Rós
# 85            Beyond the Sky      Emilio Bonito
#
#                                      uri
# 0   spotify:track:6kkwzB6hXLIONkEk9JciA6
# 1   spotify:track:3BdVeHmCKUrb4LTU0Kpw7Z
# 2   spotify:track:6PJS1eFGk0YTlBoyZGPC2K
# 3   spotify:track:6shMq3iAjg2uvn36R4MpYG
# 4   spotify:track:0Z5oEza6OKWhXJBVnlCWzl
# ..                                   ...
# 81  spotify:track:06X1J1lPc0boVEpxG6UOCB
# 82  spotify:track:7aS8e5XKVWDcbyn06mF9fz
# 83  spotify:track:1TCkrnjuurf0DNLLoJxVyd
# 84  spotify:track:4o7YmNo3syL8mtvHNhwDuL
# 85  spotify:track:08adWEXNC4zjhKZZuAVMo5
#
# [86 rows x 3 columns]

# %%
sau_df = sau_df[~ sau_df['uri'].str.contains('spotify:local')]

# %%
audio_features = [sp.audio_features(i) for i in sau_df['uri']]

# %%
audio_features = [audio_features[i][0] for i in range(len(audio_features))]

# %%
af_df = pd.DataFrame.from_dict(data = audio_features, orient = 'columns').pivot_table(index = 'uri').reset_index()
#este from_dict es para hacer un data frame de un diccionario
af_df
# Out:
#                                      uri  acousticness  danceability  \
# 0   spotify:track:067SxShIVLY65pTSTCUck8         0.897        0.3220
# 1   spotify:track:06X1J1lPc0boVEpxG6UOCB         0.947        0.1120
# 2   spotify:track:08adWEXNC4zjhKZZuAVMo5         0.353        0.5090
# 3   spotify:track:0HFklXOxyVyV0bJ55q1wxZ         0.968        0.4440
# 4   spotify:track:0J88mrTBn9k3ga1FUCXYpY         0.895        0.5000
# ..                                   ...           ...           ...
# 81  spotify:track:6vAdLrIH29ejggTSrPxYfK         0.923        0.5600
# 82  spotify:track:6vyLaQzLhCjKRdxvwztC1z         0.987        0.0810
# 83  spotify:track:70FfytITXJOz0s2xY3rOzz         0.863        0.0746
# 84  spotify:track:7aS8e5XKVWDcbyn06mF9fz         0.868        0.2980
# 85  spotify:track:7bKOKehXTXYiIz5305Cokp         0.920        0.6970
#
#     duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0        465920  0.4300             0.963    0    0.1090   -15.605     1
# 1        161027  0.0657             0.931    2    0.1120   -19.837     1
# 2        212000  0.3950             0.909    9    0.1050   -13.630     1
# 3        403041  0.2240             0.853    4    0.0729   -14.793     0
# 4        352013  0.2620             0.916    7    0.1100   -17.922     1
# ..          ...     ...               ...  ...       ...       ...   ...
# 81       222307  0.2320             0.407    7    0.0856   -11.623     0
# 82       292307  0.0776             0.954    4    0.0650   -24.144     0
# 83       458907  0.1560             0.919    9    0.1050   -24.007     0
# 84       148547  0.1480             0.843    3    0.1100   -26.245     0
# 85       113467  0.1330             0.928    0    0.2710   -25.484     1
#
#     speechiness    tempo  time_signature  valence
# 0        0.0371  160.037               4   0.0656
# 1        0.0495   56.750               4   0.0354
# 2        0.0322  144.025               4   0.0651
# 3        0.0389  109.992               4   0.0760
# 4        0.0316  120.012               4   0.0333
# ..          ...      ...             ...      ...
# 81       0.0297  119.996               5   0.1860
# 82       0.0431  169.929               3   0.0296
# 83       0.0393   80.494               5   0.0463
# 84       0.0438  108.658               4   0.0603
# 85       0.0452  103.796               4   0.2410
#
# [86 rows x 14 columns]

# %%
final_df_1 = sau_df.merge(right = af_df, on = 'uri')
final_df = pd.concat([final_df_1, track_pop], axis = 1)
final_df
# Out:
#                         song             artist  \
# 0                 Weightless      Marconi Union
# 1              The Wider Sun        Jon Hopkins
# 2              Catalina 1943             Loscil
# 3                      Theme  Jóhann Jóhannsson
# 4               Radiant City      Robin Guthrie
# ..                       ...                ...
# 81  Requiem On Frankfort Ave            Eluvium
# 82                   Candles        Jon Hopkins
# 83                Poa Alpina          Biosphere
# 84   Untitled #3 (Samskeyti)          Sigur Rós
# 85            Beyond the Sky      Emilio Bonito
#
#                                      uri  acousticness  danceability  \
# 0   spotify:track:6kkwzB6hXLIONkEk9JciA6         0.856        0.1390
# 1   spotify:track:3BdVeHmCKUrb4LTU0Kpw7Z         0.895        0.0729
# 2   spotify:track:6PJS1eFGk0YTlBoyZGPC2K         0.712        0.0855
# 3   spotify:track:6shMq3iAjg2uvn36R4MpYG         0.858        0.1290
# 4   spotify:track:0Z5oEza6OKWhXJBVnlCWzl         0.990        0.2230
# ..                                   ...           ...           ...
# 81  spotify:track:06X1J1lPc0boVEpxG6UOCB         0.947        0.1120
# 82  spotify:track:7aS8e5XKVWDcbyn06mF9fz         0.868        0.2980
# 83  spotify:track:1TCkrnjuurf0DNLLoJxVyd         0.911        0.1710
# 84  spotify:track:4o7YmNo3syL8mtvHNhwDuL         0.802        0.1150
# 85  spotify:track:08adWEXNC4zjhKZZuAVMo5         0.353        0.5090
#
#     duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0        480107  0.2200             0.831    2    0.1700   -19.974     0
# 1        154933  0.2110             0.760    3    0.1330   -17.410     1
# 2        394147  0.1760             0.933    2    0.0976   -21.240     0
# 3        203000  0.1940             0.816    9    0.3660   -15.064     0
# 4        293480  0.0828             0.828    2    0.0828   -24.326     1
# ..          ...     ...               ...  ...       ...       ...   ...
# 81       161027  0.0657             0.931    2    0.1120   -19.837     1
# 82       148547  0.1480             0.843    3    0.1100   -26.245     0
# 83       250961  0.0284             0.946    7    0.1190   -35.244     0
# 84       393400  0.2040             0.901    3    0.1050   -14.414     1
# 85       212000  0.3950             0.909    9    0.1050   -13.630     1
#
#     speechiness    tempo  time_signature  valence  popularity
# 0        0.0324   71.432               5   0.0789          65
# 1        0.0332   79.509               3   0.0393           0
# 2        0.0393   84.447               3   0.0377          18
# 3        0.0449   53.981               5   0.0655           0
# 4        0.0563  129.825               4   0.0359          35
# ..          ...      ...             ...      ...         ...
# 81       0.0495   56.750               4   0.0354           0
# 82       0.0438  108.658               4   0.0603          49
# 83       0.0374  130.284               4   0.1280           0
# 84       0.0313   90.385               4   0.0374           0
# 85       0.0322  144.025               4   0.0651          18
#
# [86 rows x 17 columns]

# %%
numericals_1 = final_df.select_dtypes(include = np.number)

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlations_matrix = numericals_1.corr()
sns.heatmap(correlations_matrix, sns.set(rc = {'figure.figsize':(12,8)}), linewidths=3, annot=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: vmin. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
