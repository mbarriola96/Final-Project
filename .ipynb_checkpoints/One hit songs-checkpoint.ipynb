# %% [markdown]
# # Predicting a one hit songs success

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# url = "https://es.wikipedia.org/wiki/Anexo:Canciones_m%C3%A1s_reproducidas_en_Spotify"

# %% [markdown]
# response = requests.get(url)
# response.status_code # 200 status code means OK!

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# soup

# %% [markdown]
# prestab = soup.select("table")[0]
#
# prestab.select("tr td")

# %% [markdown]
# song = []
# for title in prestab.select("tr td:nth-child(2)"):
#     song.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# song

# %% [markdown]
# artist = []
# for title in prestab.select("tr td:nth-child(3)"):
#     artist.append(title.get_text())
#     #print(title.get_text())
# #mw-content-text > div.mw-parser-output > table:nth-child(9) > tbody > tr:nth-child(4) > td:nth-child(3)

# %% [markdown]
# artist

# %% [markdown]
# replays = []
# for title in prestab.select("tr td:nth-child(5)"):
#     replays.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# replays

# %% [markdown]
# song = pd.DataFrame(song)
# artist = pd.DataFrame(artist)
# replays = pd.DataFrame(replays)
# print(len(song))
# print(len(artist))
# print(len(replays))

# %% [markdown]
# df_1 = pd.concat([replays], axis = 1)
# df_1.columns = ['replays (billion)']
# df_1 = df_1.replace(',','', regex=True)
# df_1 = df_1.astype(float)
# df_1

# %% [markdown]
# ## Getting access to spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='<your client id here>',
#                                                           client_secret='<your client secret here>'))

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# ### Coding in spotify

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("1CDCoUIcKVtsSZA06YeGvp")
len(all_tracks)
# Out:
# 96

# %%
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"]) for artist in track["artists"]]

# %%
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

# %%
#flattening is not in the standard library but used a lot. you'll thank me later
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
def get_name_artists_from_playlist(input_playlist):
    return list(map(get_name_artist_from_playlist_item, input_playlist))

# %%
song_artist = get_name_artists_from_playlist(all_tracks)
len(song_artist)
# Out:
# 96

# %%
song_artist = [song_artist[i][0] for i in range(len(song_artist))]

# %%
df = pd.DataFrame(song_artist, columns = ['song', 'artist'])
df
# Out:
#                                         song               artist
# 0                        The Final Countdown               Europe
# 1                               Unbelievable                  EMF
# 2                       Maniac - Re-Recorded     Michael Sembello
# 3   Wipe Out - Hit Version / Extended Ending         The Surfaris
# 4                                 Your Woman           White Town
# ..                                       ...                  ...
# 91                                Take on Me                 a-ha
# 92                               O-o-h Child  The Five Stairsteps
# 93                                      Torn    Natalie Imbruglia
# 94                          Rapper's Delight   The Sugarhill Gang
# 95                  I Melt with You (7" Mix)       Modern English
#
# [96 rows x 2 columns]

# %%
uris = [(all_tracks[i]["track"]["uri"]) for i in range(len(all_tracks))]

uris = pd.DataFrame(uris, columns = ['uri'])
uris
# Out:
#                                      uri
# 0   spotify:track:3MrRksHupTVEQ7YbA0FsZK
# 1   spotify:track:2ENmkocNNewTRbuNd6WJpR
# 2   spotify:track:0UPAUPQew4Ezrni8X6vFDK
# 3   spotify:track:4anUinKv803lyDD1vaSXhU
# 4   spotify:track:4ACxa9buEUnOdYEoPcnMpi
# ..                                   ...
# 91  spotify:track:2WfaOiMkCvy7F5fcp2zZ8L
# 92  spotify:track:74JdR9aXE6I74oS1BVRsvb
# 93  spotify:track:0KDaN0HL3TcJVTbXlQCEsS
# 94  spotify:track:0FWhGmPVxLI6jOVF0wjALa
# 95  spotify:track:0Cc1TGI0VBQDltJJ4a4dmj
#
# [96 rows x 1 columns]

# %%
track_pop = [(all_tracks[i]["track"]["popularity"]) for i in range(len(all_tracks))]
track_pop = pd.DataFrame(track_pop, columns = ['popularity'])
track_pop
# Out:
#     popularity
# 0           74
# 1            0
# 2            0
# 3           48
# 4           64
# ..         ...
# 91          81
# 92          62
# 93          56
# 94          52
# 95           0
#
# [96 rows x 1 columns]

# %%
track_pop['popularity'].value_counts()
# Out:
# 0     22
# 63     4
# 54     4
# 59     3
# 62     3
# 58     3
# 52     3
# 49     3
# 67     3
# 34     2
# 53     2
# 55     2
# 60     2
# 47     2
# 66     2
# 72     2
# 46     2
# 56     2
# 65     2
# 20     1
# 61     1
# 71     1
# 74     1
# 29     1
# 21     1
# 36     1
# 17     1
# 68     1
# 39     1
# 70     1
# 30     1
# 51     1
# 41     1
# 77     1
# 1      1
# 8      1
# 44     1
# 50     1
# 38     1
# 42     1
# 45     1
# 57     1
# 37     1
# 69     1
# 64     1
# 48     1
# 81     1
# Name: popularity, dtype: int64

# %%
track_pop['popularity'] = track_pop['popularity'].astype(float)
track_pop['popularity'] = [ 1 if i>=50 else 0 for i in track_pop['popularity']]
track_pop['popularity'].value_counts()
# Out:
# 1    49
# 0    47
# Name: popularity, dtype: int64

# %%
sau_df = pd.concat([df, uris], axis = 1)
sau_df
# Out:
#                                         song               artist  \
# 0                        The Final Countdown               Europe
# 1                               Unbelievable                  EMF
# 2                       Maniac - Re-Recorded     Michael Sembello
# 3   Wipe Out - Hit Version / Extended Ending         The Surfaris
# 4                                 Your Woman           White Town
# ..                                       ...                  ...
# 91                                Take on Me                 a-ha
# 92                               O-o-h Child  The Five Stairsteps
# 93                                      Torn    Natalie Imbruglia
# 94                          Rapper's Delight   The Sugarhill Gang
# 95                  I Melt with You (7" Mix)       Modern English
#
#                                      uri
# 0   spotify:track:3MrRksHupTVEQ7YbA0FsZK
# 1   spotify:track:2ENmkocNNewTRbuNd6WJpR
# 2   spotify:track:0UPAUPQew4Ezrni8X6vFDK
# 3   spotify:track:4anUinKv803lyDD1vaSXhU
# 4   spotify:track:4ACxa9buEUnOdYEoPcnMpi
# ..                                   ...
# 91  spotify:track:2WfaOiMkCvy7F5fcp2zZ8L
# 92  spotify:track:74JdR9aXE6I74oS1BVRsvb
# 93  spotify:track:0KDaN0HL3TcJVTbXlQCEsS
# 94  spotify:track:0FWhGmPVxLI6jOVF0wjALa
# 95  spotify:track:0Cc1TGI0VBQDltJJ4a4dmj
#
# [96 rows x 3 columns]

# %%
sau_df = sau_df[~ sau_df['uri'].str.contains('spotify:local')]

# %%
audio_features = [sp.audio_features(i) for i in sau_df['uri']]

# %%
audio_features = [audio_features[i][0] for i in range(len(audio_features))]

# %%
af_df = pd.DataFrame.from_dict(data = audio_features, orient = 'columns').pivot_table(index = 'uri').reset_index()
#este from_dict es para hacer un data frame de un diccionario
af_df
# Out:
#                                      uri  acousticness  danceability  \
# 0   spotify:track:027XxddlYnivk8t6AeKFtB      0.776000         0.473
# 1   spotify:track:02lTDOxHeXTHsdwXoz6lpC      0.083000         0.269
# 2   spotify:track:0BB9eUBBaaX6GALSYNcEp7      0.006000         0.554
# 3   spotify:track:0Cc1TGI0VBQDltJJ4a4dmj      0.000433         0.463
# 4   spotify:track:0EMmVUYs9ZZRHtlADB88uz      0.648000         0.450
# ..                                   ...           ...           ...
# 91  spotify:track:7cz70nyRXlCJOE85whEkgU      0.001520         0.361
# 92  spotify:track:7dOZxMY4U4YZ3eFwOTABXK      0.013300         0.497
# 93  spotify:track:7rGOWzo4evAQQ2FzrSKp0B      0.445000         0.708
# 94  spotify:track:7ufDF5ePKsnxYgP0DAZoZE      0.739000         0.657
# 95  spotify:track:7wnCidHrM3QrG6KXC2A8zs      0.003360         0.508
#
#     duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0        138475   0.775          0.000031   10    0.2420    -6.463     1
# 1        299507   0.895          0.002660    9    0.1530    -6.382     1
# 2        196800   0.851          0.024200    6    0.4050   -10.526     0
# 3        228667   0.794          0.000215    0    0.0522    -7.506     1
# 4        287307   0.658          0.000003    2    0.2640    -7.064     1
# ..          ...     ...               ...  ...       ...       ...   ...
# 91       217267   0.901          0.000263    4    0.2860    -4.133     0
# 92       251067   0.704          0.000394    0    0.3710   -12.056     1
# 93       156160   0.616          0.000000    5    0.2990   -10.827     1
# 94       181133   0.435          0.000000   10    0.1670   -15.707     1
# 95       306307   0.740          0.475000    2    0.1720   -10.288     1
#
#     speechiness    tempo  time_signature  valence
# 0        0.4950  199.045               4    0.526
# 1        0.1180  168.479               4    0.160
# 2        0.0334  128.103               4    0.960
# 3        0.0551  156.172               4    0.573
# 4        0.0472  106.799               4    0.781
# ..          ...      ...             ...      ...
# 91       0.0443  144.970               4    0.482
# 92       0.0346  164.679               4    0.582
# 93       0.1980  177.061               4    0.908
# 94       0.0552  135.975               4    0.771
# 95       0.0342  146.164               4    0.654
#
# [96 rows x 14 columns]

# %%
final_df_1 = sau_df.merge(right = af_df, on = 'uri')
final_df = pd.concat([final_df_1, track_pop], axis = 1)
final_df
# Out:
#                                         song               artist  \
# 0                        The Final Countdown               Europe
# 1                               Unbelievable                  EMF
# 2                       Maniac - Re-Recorded     Michael Sembello
# 3   Wipe Out - Hit Version / Extended Ending         The Surfaris
# 4                                 Your Woman           White Town
# ..                                       ...                  ...
# 91                                Take on Me                 a-ha
# 92                               O-o-h Child  The Five Stairsteps
# 93                                      Torn    Natalie Imbruglia
# 94                          Rapper's Delight   The Sugarhill Gang
# 95                  I Melt with You (7" Mix)       Modern English
#
#                                      uri  acousticness  danceability  \
# 0   spotify:track:3MrRksHupTVEQ7YbA0FsZK      0.062800         0.529
# 1   spotify:track:2ENmkocNNewTRbuNd6WJpR      0.000341         0.637
# 2   spotify:track:0UPAUPQew4Ezrni8X6vFDK      0.004820         0.637
# 3   spotify:track:4anUinKv803lyDD1vaSXhU      0.385000         0.336
# 4   spotify:track:4ACxa9buEUnOdYEoPcnMpi      0.033000         0.815
# ..                                   ...           ...           ...
# 91  spotify:track:2WfaOiMkCvy7F5fcp2zZ8L      0.018000         0.573
# 92  spotify:track:74JdR9aXE6I74oS1BVRsvb      0.001540         0.488
# 93  spotify:track:0KDaN0HL3TcJVTbXlQCEsS      0.064700         0.575
# 94  spotify:track:0FWhGmPVxLI6jOVF0wjALa      0.465000         0.900
# 95  spotify:track:0Cc1TGI0VBQDltJJ4a4dmj      0.000433         0.463
#
#     duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0        310333   0.843          0.000827    6    0.0608    -6.908     0
# 1        209813   0.849          0.038600    1    0.1410    -6.855     1
# 2        259135   0.730          0.000449    3    0.0251    -7.368     0
# 3        157760   0.636          0.909000    0    0.4140   -13.785     1
# 4        259893   0.605          0.684000    5    0.1140    -9.118     0
# ..          ...     ...               ...  ...       ...       ...   ...
# 91       225280   0.902          0.001250    6    0.0928    -7.638     0
# 92       197160   0.754          0.000024    5    0.6780    -7.950     0
# 93       244667   0.886          0.000187    5    0.7090    -5.182     1
# 94       427360   0.845          0.000000   11    0.0724    -7.306     0
# 95       228667   0.794          0.000215    0    0.0522    -7.506     1
#
#     speechiness    tempo  time_signature  valence  popularity
# 0        0.0616  117.662               4    0.188           1
# 1        0.0362  104.074               4    0.936           0
# 2        0.0340  157.202               4    0.829           0
# 3        0.0374  152.423               4    0.521           0
# 4        0.0368  102.642               4    0.795           1
# ..          ...      ...             ...      ...         ...
# 91       0.0540   84.412               4    0.876           1
# 92       0.0381   88.368               4    0.664           1
# 93       0.0340   96.310               4    0.609           1
# 94       0.2570  111.187               4    0.914           1
# 95       0.0551  156.172               4    0.573           0
#
# [96 rows x 17 columns]

# %%
numericals_1 = final_df.select_dtypes(include = np.number)

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlations_matrix = numericals_1.corr()
sns.heatmap(correlations_matrix, sns.set(rc = {'figure.figsize':(12,8)}), linewidths=3, annot=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: vmin. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
