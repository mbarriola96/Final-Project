# %% [markdown]
# # Predicting a song's for sleeping success

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# url = "https://es.wikipedia.org/wiki/Anexo:Canciones_m%C3%A1s_reproducidas_en_Spotify"

# %% [markdown]
# response = requests.get(url)
# response.status_code # 200 status code means OK!

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# soup

# %% [markdown]
# prestab = soup.select("table")[0]
#
# prestab.select("tr td")

# %% [markdown]
# song = []
# for title in prestab.select("tr td:nth-child(2)"):
#     song.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# song

# %% [markdown]
# artist = []
# for title in prestab.select("tr td:nth-child(3)"):
#     artist.append(title.get_text())
#     #print(title.get_text())
# #mw-content-text > div.mw-parser-output > table:nth-child(9) > tbody > tr:nth-child(4) > td:nth-child(3)

# %% [markdown]
# artist

# %% [markdown]
# replays = []
# for title in prestab.select("tr td:nth-child(5)"):
#     replays.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# replays

# %% [markdown]
# song = pd.DataFrame(song)
# artist = pd.DataFrame(artist)
# replays = pd.DataFrame(replays)
# print(len(song))
# print(len(artist))
# print(len(replays))

# %% [markdown]
# df_1 = pd.concat([replays], axis = 1)
# df_1.columns = ['replays (billion)']
# df_1 = df_1.replace(',','', regex=True)
# df_1 = df_1.astype(float)
# df_1

# %% [markdown]
# ## Getting access to spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='<your client id here>',
#                                                           client_secret='<your client secret here>'))

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# ### Coding in spotify

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("37i9dQZF1DWStLt4f1zJ6I")
len(all_tracks)
# Out:
# 99

# %%
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"]) for artist in track["artists"]]

# %%
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

# %%
#flattening is not in the standard library but used a lot. you'll thank me later
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
def get_name_artists_from_playlist(input_playlist):
    return list(map(get_name_artist_from_playlist_item, input_playlist))

# %%
song_artist = get_name_artists_from_playlist(all_tracks)
len(song_artist)
# Out:
# 99

# %%
song_artist = [song_artist[i][0] for i in range(len(song_artist))]

# %%
df = pd.DataFrame(song_artist, columns = ['song', 'artist'])
df
# Out:
#                     song         artist
# 0   Nils has a new piano     Nils Frahm
# 1          Simple Beauty     Martin Fox
# 2             Song for A    Charlie Key
# 3        Northern Lights    Robbie Hees
# 4          Speck of Dust        Fellows
# ..                   ...            ...
# 94      By The Open Fire    Reza Mouzza
# 95         Waltz With Me   Rachel Knott
# 96     A Thousand Dreams  Vic Hamberlin
# 97   One Morning In June    Greg Barley
# 98           Old Friends        Juliana
#
# [99 rows x 2 columns]

# %%
uris = [(all_tracks[i]["track"]["uri"]) for i in range(len(all_tracks))]

uris = pd.DataFrame(uris, columns = ['uri'])
uris
# Out:
#                                      uri
# 0   spotify:track:37p1PzVVLIbNWJlRHtwtPP
# 1   spotify:track:3a6enSby0Rw9mrRPKDvqEL
# 2   spotify:track:181ybi6b0dYJBcQzETKv67
# 3   spotify:track:54MKow5YALnqRH3Ys1R31y
# 4   spotify:track:0M7gRVPeVUAUDbS8N0kmdb
# ..                                   ...
# 94  spotify:track:0LnmUpHTZQUfnWFxdgw2QV
# 95  spotify:track:5lFEnPOthqYPWrw43urIR6
# 96  spotify:track:2R8PENzApXLgAMNeEVxrzN
# 97  spotify:track:3rdau6vlFbeLv9rKPLcaNw
# 98  spotify:track:77q2I17hdHukGdJJpxYOke
#
# [99 rows x 1 columns]

# %%
track_pop = [(all_tracks[i]["track"]["popularity"]) for i in range(len(all_tracks))]
track_pop = pd.DataFrame(track_pop, columns = ['popularity'])
track_pop
# Out:
#     popularity
# 0            0
# 1           45
# 2           48
# 3           43
# 4           43
# ..         ...
# 94          38
# 95          38
# 96          45
# 97          38
# 98          41
#
# [99 rows x 1 columns]

# %%
track_pop['popularity'].value_counts()
# Out:
# 38    14
# 0     13
# 37    11
# 36    11
# 41     9
# 39     8
# 43     6
# 40     5
# 48     4
# 44     4
# 42     4
# 35     3
# 45     2
# 53     1
# 46     1
# 49     1
# 47     1
# 34     1
# Name: popularity, dtype: int64

# %%
# track_pop['popularity'] = track_pop['popularity'].astype(float)
# track_pop['popularity'] = [ 1 if i>=9 else 0 for i in track_pop['popularity']]
# track_pop['popularity'].value_counts()

# %%
sau_df = pd.concat([df, uris], axis = 1)
sau_df
# Out:
#                     song         artist                                   uri
# 0   Nils has a new piano     Nils Frahm  spotify:track:37p1PzVVLIbNWJlRHtwtPP
# 1          Simple Beauty     Martin Fox  spotify:track:3a6enSby0Rw9mrRPKDvqEL
# 2             Song for A    Charlie Key  spotify:track:181ybi6b0dYJBcQzETKv67
# 3        Northern Lights    Robbie Hees  spotify:track:54MKow5YALnqRH3Ys1R31y
# 4          Speck of Dust        Fellows  spotify:track:0M7gRVPeVUAUDbS8N0kmdb
# ..                   ...            ...                                   ...
# 94      By The Open Fire    Reza Mouzza  spotify:track:0LnmUpHTZQUfnWFxdgw2QV
# 95         Waltz With Me   Rachel Knott  spotify:track:5lFEnPOthqYPWrw43urIR6
# 96     A Thousand Dreams  Vic Hamberlin  spotify:track:2R8PENzApXLgAMNeEVxrzN
# 97   One Morning In June    Greg Barley  spotify:track:3rdau6vlFbeLv9rKPLcaNw
# 98           Old Friends        Juliana  spotify:track:77q2I17hdHukGdJJpxYOke
#
# [99 rows x 3 columns]

# %%
sau_df = sau_df[~ sau_df['uri'].str.contains('spotify:local')]

# %%
audio_features = [sp.audio_features(i) for i in sau_df['uri']]

# %%
audio_features = [audio_features[i][0] for i in range(len(audio_features))]

# %%
af_df = pd.DataFrame.from_dict(data = audio_features, orient = 'columns').pivot_table(index = 'uri').reset_index()
#este from_dict es para hacer un data frame de un diccionario
af_df
# Out:
#                                      uri  acousticness  danceability  \
# 0   spotify:track:02vL85IGFIt1mhLWbdjgHU         0.987         0.409
# 1   spotify:track:0DxwlHSCxpL3vGK9yqnITe         0.994         0.734
# 2   spotify:track:0IbCvSXkxMGhqg7QJ51Zig         0.991         0.345
# 3   spotify:track:0LnmUpHTZQUfnWFxdgw2QV         0.994         0.609
# 4   spotify:track:0M7gRVPeVUAUDbS8N0kmdb         0.990         0.410
# ..                                   ...           ...           ...
# 94  spotify:track:7AlNTcQorRnNijLoA5aIDs         0.993         0.803
# 95  spotify:track:7d4i1kAUl9IZR4i46klvNT         0.942         0.191
# 96  spotify:track:7m38DtprSwH6eVRYadgNww         0.871         0.144
# 97  spotify:track:7oeA6KfI7yKmjCQ26tppRF         0.994         0.474
# 98  spotify:track:7xzeJbiPtEJY5aYqkB2fwY         0.987         0.372
#
#     duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0        182800  0.0212             0.934    4    0.1140   -27.546     0
# 1        218627  0.0289             0.961    1    0.1000   -22.149     1
# 2        112656  0.0752             0.970   10    0.1100   -21.612     1
# 3        143168  0.0357             0.942    6    0.1060   -22.639     0
# 4        247250  0.0463             0.925    6    0.0884   -27.399     0
# ..          ...     ...               ...  ...       ...       ...   ...
# 94       144255  0.0789             0.954   10    0.1170   -18.115     0
# 95       270933  0.2110             0.869    8    0.1110   -18.551     0
# 96       166000  0.2250             0.965    2    0.0948   -17.758     1
# 97       122012  0.0300             0.954    3    0.0888   -33.810     0
# 98       128000  0.1010             0.827    7    0.1220   -22.378     1
#
#     speechiness    tempo  time_signature  valence
# 0        0.0500   74.880               4   0.1850
# 1        0.0516   68.013               4   0.3420
# 2        0.0604  175.192               4   0.0930
# 3        0.0492  100.028               4   0.1750
# 4        0.0445   72.708               4   0.2970
# ..          ...      ...             ...      ...
# 94       0.0518  120.033               4   0.3790
# 95       0.0384  137.339               5   0.0540
# 96       0.0472   71.543               4   0.0310
# 97       0.0616  173.979               4   0.2340
# 98       0.0491   99.318               3   0.0391
#
# [99 rows x 14 columns]

# %%
final_df_1 = sau_df.merge(right = af_df, on = 'uri')
final_df = pd.concat([final_df_1, track_pop], axis = 1)
final_df
# Out:
#                     song         artist                                   uri  \
# 0   Nils has a new piano     Nils Frahm  spotify:track:37p1PzVVLIbNWJlRHtwtPP
# 1          Simple Beauty     Martin Fox  spotify:track:3a6enSby0Rw9mrRPKDvqEL
# 2             Song for A    Charlie Key  spotify:track:181ybi6b0dYJBcQzETKv67
# 3        Northern Lights    Robbie Hees  spotify:track:54MKow5YALnqRH3Ys1R31y
# 4          Speck of Dust        Fellows  spotify:track:0M7gRVPeVUAUDbS8N0kmdb
# ..                   ...            ...                                   ...
# 94      By The Open Fire    Reza Mouzza  spotify:track:0LnmUpHTZQUfnWFxdgw2QV
# 95         Waltz With Me   Rachel Knott  spotify:track:5lFEnPOthqYPWrw43urIR6
# 96     A Thousand Dreams  Vic Hamberlin  spotify:track:2R8PENzApXLgAMNeEVxrzN
# 97   One Morning In June    Greg Barley  spotify:track:3rdau6vlFbeLv9rKPLcaNw
# 98           Old Friends        Juliana  spotify:track:77q2I17hdHukGdJJpxYOke
#
#     acousticness  danceability  duration_ms   energy  instrumentalness  key  \
# 0          0.992         0.371       245110  0.04430             0.915    0
# 1          0.994         0.538        94206  0.01480             0.929    0
# 2          0.992         0.466       145812  0.00472             0.938    5
# 3          0.995         0.731       247791  0.01110             0.966    0
# 4          0.990         0.410       247250  0.04630             0.925    6
# ..           ...           ...          ...      ...               ...  ...
# 94         0.994         0.609       143168  0.03570             0.942    6
# 95         0.994         0.655       151148  0.07390             0.965   11
# 96         0.995         0.666       231383  0.09650             0.970    1
# 97         0.994         0.367       147883  0.03810             0.913    0
# 98         0.992         0.498       295250  0.12300             0.924    0
#
#     liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0     0.1480   -30.338     0       0.0451  128.807               3    0.144
# 1     0.1020   -21.967     1       0.0856   70.826               3    0.328
# 2     0.0712   -28.546     1       0.0531   81.181               4    0.233
# 3     0.1110   -22.684     0       0.1110   72.132               4    0.472
# 4     0.0884   -27.399     0       0.0445   72.708               4    0.297
# ..       ...       ...   ...          ...      ...             ...      ...
# 94    0.1060   -22.639     0       0.0492  100.028               4    0.175
# 95    0.1160   -19.939     1       0.0594   79.888               3    0.379
# 96    0.1060   -21.897     1       0.0598   69.986               3    0.166
# 97    0.1100   -27.440     1       0.0751  104.400               3    0.153
# 98    0.1030   -20.059     1       0.0675   74.240               4    0.166
#
#     popularity
# 0            0
# 1           45
# 2           48
# 3           43
# 4           43
# ..         ...
# 94          38
# 95          38
# 96          45
# 97          38
# 98          41
#
# [99 rows x 17 columns]

# %%
numericals_1 = final_df.select_dtypes(include = np.number)

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlations_matrix = numericals_1.corr()
sns.heatmap(correlations_matrix, sns.set(rc = {'figure.figsize':(12,8)}), linewidths=3, annot=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: vmin. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
