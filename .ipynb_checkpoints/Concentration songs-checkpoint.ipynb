# %% [markdown]
# # Predicting a song for concentration's success

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# url = "https://es.wikipedia.org/wiki/Anexo:Canciones_m%C3%A1s_reproducidas_en_Spotify"

# %% [markdown]
# response = requests.get(url)
# response.status_code # 200 status code means OK!

# %% [markdown]
# soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# soup

# %% [markdown]
# prestab = soup.select("table")[0]
#
# prestab.select("tr td")

# %% [markdown]
# song = []
# for title in prestab.select("tr td:nth-child(2)"):
#     song.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# song

# %% [markdown]
# artist = []
# for title in prestab.select("tr td:nth-child(3)"):
#     artist.append(title.get_text())
#     #print(title.get_text())
# #mw-content-text > div.mw-parser-output > table:nth-child(9) > tbody > tr:nth-child(4) > td:nth-child(3)

# %% [markdown]
# artist

# %% [markdown]
# replays = []
# for title in prestab.select("tr td:nth-child(5)"):
#     replays.append(title.get_text())
#     #print(title.get_text())

# %% [markdown]
# replays

# %% [markdown]
# song = pd.DataFrame(song)
# artist = pd.DataFrame(artist)
# replays = pd.DataFrame(replays)
# print(len(song))
# print(len(artist))
# print(len(replays))

# %% [markdown]
# df_1 = pd.concat([replays], axis = 1)
# df_1.columns = ['replays (billion)']
# df_1 = df_1.replace(',','', regex=True)
# df_1 = df_1.astype(float)
# df_1

# %% [markdown]
# ## Getting access to spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='<your client id here>',
#                                                           client_secret='<your client secret here>'))

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %% [markdown]
# ### Coding in spotify

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("098ZdsH5LSrCbTkTpyWeim")
len(all_tracks)
# Out:
# 100

# %%
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"]) for artist in track["artists"]]

# %%
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

# %%
#flattening is not in the standard library but used a lot. you'll thank me later
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
def get_name_artists_from_playlist(input_playlist):
    return list(map(get_name_artist_from_playlist_item, input_playlist))

# %%
song_artist = get_name_artists_from_playlist(all_tracks)
len(song_artist)
# Out:
# 100

# %%
song_artist = [song_artist[i][0] for i in range(len(song_artist))]

# %%
df = pd.DataFrame(song_artist, columns = ['song', 'artist'])
df
# Out:
#                                          song  \
# 0                    Late Night Concentration
# 1           Morning Coffee (Background Music)
# 2             Good Study Music for University
# 3                                  Exam Study
# 4      Piano Music (How to Study for an Exam)
# ..                                        ...
# 95                                 Deep Focus
# 96                             Koto Zen Music
# 97                     Mindfulness Meditation
# 98  Osho Kundalini Meditation 2nd Stage Dance
# 99              Calm Mind Buddhist Meditation
#
#                                   artist
# 0              Concentration Study Music
# 1                        Brainwaves Mike
# 2               Office Music Specialists
# 3   Exam Study Classical Music Orchestra
# 4   Exam Study Classical Music Orchestra
# ..                                   ...
# 95                       Alexander Focus
# 96                     Fast Learning PhD
# 97                     Fast Learning PhD
# 98                  Ambient Music Series
# 99                  Ambient Music Series
#
# [100 rows x 2 columns]

# %%
uris = [(all_tracks[i]["track"]["uri"]) for i in range(len(all_tracks))]

uris = pd.DataFrame(uris, columns = ['uri'])
uris
# Out:
#                                      uri
# 0   spotify:track:5Y97PSkA4crfXD3V2lgsXg
# 1   spotify:track:4ZvogaQxcorh2Rq9zespUJ
# 2   spotify:track:2AsH4iYxYMNsIw3KRXx1p5
# 3   spotify:track:4gfKRgLk1t1Ib5yxgjjaXN
# 4   spotify:track:1zEwjCb210yWCv2QMXOtG7
# ..                                   ...
# 95  spotify:track:59rf93OidI15Onnm5X9kCH
# 96  spotify:track:2XhRQu8MmQWSSkFEybxVZG
# 97  spotify:track:3vt4k51B2Iix6bWrxOpFIC
# 98  spotify:track:54GTEILTHuy8jZ1OU8YXKZ
# 99  spotify:track:36autIc4YhHhNAHzJxA1Kt
#
# [100 rows x 1 columns]

# %%
track_pop = [(all_tracks[i]["track"]["popularity"]) for i in range(len(all_tracks))]
track_pop = pd.DataFrame(track_pop, columns = ['popularity'])
track_pop
# Out:
#     popularity
# 0            0
# 1            0
# 2            0
# 3            3
# 4            2
# ..         ...
# 95           3
# 96           3
# 97           3
# 98           0
# 99           0
#
# [100 rows x 1 columns]

# %%
track_pop['popularity'].value_counts()
# Out:
# 0     44
# 1     23
# 3     10
# 2     10
# 4      6
# 9      1
# 18     1
# 5      1
# 11     1
# 13     1
# 6      1
# 8      1
# Name: popularity, dtype: int64

# %%
# track_pop['popularity'] = track_pop['popularity'].astype(float)
# track_pop['popularity'] = [ 1 if i>=9 else 0 for i in track_pop['popularity']]
# track_pop['popularity'].value_counts()

# %%
sau_df = pd.concat([df, uris], axis = 1)
sau_df
# Out:
#                                          song  \
# 0                    Late Night Concentration
# 1           Morning Coffee (Background Music)
# 2             Good Study Music for University
# 3                                  Exam Study
# 4      Piano Music (How to Study for an Exam)
# ..                                        ...
# 95                                 Deep Focus
# 96                             Koto Zen Music
# 97                     Mindfulness Meditation
# 98  Osho Kundalini Meditation 2nd Stage Dance
# 99              Calm Mind Buddhist Meditation
#
#                                   artist                                   uri
# 0              Concentration Study Music  spotify:track:5Y97PSkA4crfXD3V2lgsXg
# 1                        Brainwaves Mike  spotify:track:4ZvogaQxcorh2Rq9zespUJ
# 2               Office Music Specialists  spotify:track:2AsH4iYxYMNsIw3KRXx1p5
# 3   Exam Study Classical Music Orchestra  spotify:track:4gfKRgLk1t1Ib5yxgjjaXN
# 4   Exam Study Classical Music Orchestra  spotify:track:1zEwjCb210yWCv2QMXOtG7
# ..                                   ...                                   ...
# 95                       Alexander Focus  spotify:track:59rf93OidI15Onnm5X9kCH
# 96                     Fast Learning PhD  spotify:track:2XhRQu8MmQWSSkFEybxVZG
# 97                     Fast Learning PhD  spotify:track:3vt4k51B2Iix6bWrxOpFIC
# 98                  Ambient Music Series  spotify:track:54GTEILTHuy8jZ1OU8YXKZ
# 99                  Ambient Music Series  spotify:track:36autIc4YhHhNAHzJxA1Kt
#
# [100 rows x 3 columns]

# %%
sau_df = sau_df[~ sau_df['uri'].str.contains('spotify:local')]

# %%
audio_features = [sp.audio_features(i) for i in sau_df['uri']]

# %%
audio_features = [audio_features[i][0] for i in range(len(audio_features))]

# %%
af_df = pd.DataFrame.from_dict(data = audio_features, orient = 'columns').pivot_table(index = 'uri').reset_index()
#este from_dict es para hacer un data frame de un diccionario
af_df
# Out:
#                                      uri  acousticness  danceability  \
# 0   spotify:track:04FKSs5LN0gmw3RVwM63Ly         0.984        0.2570
# 1   spotify:track:07RyZWuUNbDtLc2wCpNgUn         0.992        0.1640
# 2   spotify:track:0D44s9sAPMxFZIz77WK1My         0.981        0.0892
# 3   spotify:track:0L5nzfrmki6rXImm6THsjp         0.925        0.0705
# 4   spotify:track:0PL0SU8mxu3LaHsYjeImVq         0.959        0.1220
# ..                                   ...           ...           ...
# 95  spotify:track:7qAAYjoFJt1Ar3R7s5WujZ         0.935        0.1780
# 96  spotify:track:7qLf0KclTaK5lGI4RgyP8e         0.980        0.3020
# 97  spotify:track:7qhG1nrUHcdQY61ack39q4         0.914        0.2270
# 98  spotify:track:7qotYizk0uvLWdf6oeZfL8         0.989        0.2660
# 99  spotify:track:7tvmi5RCfCD3ksROcY5D1P         0.987        0.1530
#
#     duration_ms   energy  instrumentalness  key  liveness  loudness  mode  \
# 0        243880  0.04100          0.694000    7    0.0589   -25.735     0
# 1        401000  0.01140          0.921000    1    0.0926   -32.185     0
# 2        399000  0.09500          0.962000    8    0.0964   -22.450     1
# 3        385999  0.02590          0.891000   10    0.0973   -35.297     0
# 4        346906  0.07280          0.950000    5    0.1760   -24.988     0
# ..          ...      ...               ...  ...       ...       ...   ...
# 95       241179  0.08120          0.933000    2    0.1140   -27.577     0
# 96       233999  0.12200          0.952000   11    0.1150   -25.595     1
# 97       246000  0.26200          0.000067    2    0.1010   -22.669     0
# 98       254862  0.00384          0.954000    7    0.0829   -29.977     1
# 99       249000  0.14700          0.932000    4    0.1740   -20.073     0
#
#     speechiness    tempo  time_signature  valence
# 0        0.0442  128.233               4   0.0371
# 1        0.0489  137.735               3   0.0693
# 2        0.0424   80.713               4   0.0355
# 3        0.0385   78.103               3   0.0352
# 4        0.0383   76.547               5   0.0399
# ..          ...      ...             ...      ...
# 95       0.0447  137.747               4   0.0509
# 96       0.1390  131.691               3   0.1050
# 97       0.0481   77.787               1   0.1660
# 98       0.0417   68.740               3   0.2630
# 99       0.0356  137.656               3   0.0369
#
# [100 rows x 14 columns]

# %%
final_df_1 = sau_df.merge(right = af_df, on = 'uri')
final_df = pd.concat([final_df_1, track_pop], axis = 1)
final_df
# Out:
#                                          song  \
# 0                    Late Night Concentration
# 1           Morning Coffee (Background Music)
# 2             Good Study Music for University
# 3                                  Exam Study
# 4      Piano Music (How to Study for an Exam)
# ..                                        ...
# 95                                 Deep Focus
# 96                             Koto Zen Music
# 97                     Mindfulness Meditation
# 98  Osho Kundalini Meditation 2nd Stage Dance
# 99              Calm Mind Buddhist Meditation
#
#                                   artist  \
# 0              Concentration Study Music
# 1                        Brainwaves Mike
# 2               Office Music Specialists
# 3   Exam Study Classical Music Orchestra
# 4   Exam Study Classical Music Orchestra
# ..                                   ...
# 95                       Alexander Focus
# 96                     Fast Learning PhD
# 97                     Fast Learning PhD
# 98                  Ambient Music Series
# 99                  Ambient Music Series
#
#                                      uri  acousticness  danceability  \
# 0   spotify:track:5Y97PSkA4crfXD3V2lgsXg         0.990        0.1400
# 1   spotify:track:4ZvogaQxcorh2Rq9zespUJ         0.961        0.1890
# 2   spotify:track:2AsH4iYxYMNsIw3KRXx1p5         0.991        0.1910
# 3   spotify:track:4gfKRgLk1t1Ib5yxgjjaXN         0.994        0.3550
# 4   spotify:track:1zEwjCb210yWCv2QMXOtG7         0.994        0.3830
# ..                                   ...           ...           ...
# 95  spotify:track:59rf93OidI15Onnm5X9kCH         0.824        0.0774
# 96  spotify:track:2XhRQu8MmQWSSkFEybxVZG         0.741        0.1750
# 97  spotify:track:3vt4k51B2Iix6bWrxOpFIC         0.981        0.2720
# 98  spotify:track:54GTEILTHuy8jZ1OU8YXKZ         0.835        0.7890
# 99  spotify:track:36autIc4YhHhNAHzJxA1Kt         0.952        0.1970
#
#     duration_ms   energy  instrumentalness  key  liveness  loudness  mode  \
# 0        234057  0.10300             0.896   10    0.1070   -25.911     0
# 1        378194  0.07720             0.830    9    0.1120   -24.746     1
# 2        203593  0.02330             0.975    4    0.1170   -26.733     1
# 3        250518  0.00893             0.959    5    0.0799   -32.804     0
# 4        212312  0.01070             0.918    3    0.1960   -21.285     1
# ..          ...      ...               ...  ...       ...       ...   ...
# 95       145500  0.06400             0.964    2    0.1060   -23.890     1
# 96       371143  0.00353             0.101    7    0.0827   -31.877     1
# 97       378207  0.10400             0.938   11    0.0925   -21.976     0
# 98       181736  0.54700             0.911    1    0.0951   -19.426     1
# 99       195796  0.13300             0.510    3    0.1130   -19.665     1
#
#     speechiness    tempo  time_signature  valence  popularity
# 0        0.0423   72.946               3   0.0701           0
# 1        0.0410  130.598               1   0.0338           0
# 2        0.0340   73.324               4   0.0610           0
# 3        0.0458   70.670               3   0.1750           3
# 4        0.0438   69.056               5   0.3600           2
# ..          ...      ...             ...      ...         ...
# 95       0.0457  174.474               5   0.0379           3
# 96       0.0376   88.849               5   0.0769           3
# 97       0.0698  124.731               1   0.0330           3
# 98       0.0572  108.030               4   0.7500           0
# 99       0.0400  125.541               4   0.0316           0
#
# [100 rows x 17 columns]

# %%
numericals_1 = final_df.select_dtypes(include = np.number)

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlations_matrix = numericals_1.corr()
sns.heatmap(correlations_matrix, sns.set(rc = {'figure.figsize':(12,8)}), linewidths=3, annot=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: vmin. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
